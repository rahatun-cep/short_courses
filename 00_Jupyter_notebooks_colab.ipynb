# %% [markdown]
# ## Getting started with Jupyter notebooks
#
# ### Running a cell
# To execute code within a cell, select that cell and either (1) hit `Shift` and `Enter` or (2) hit the run button (the right pointing arrow) above.

# %%
1 + 1
2 + 2

# %% [markdown]
# If you're new to jupyter notebooks, note that only the last line of a cell prints by default when you execute that cell and that you can suppress this output with a semicolon

# %%
println(1 + 1);
2 + 2

# %% [markdown]
# ### How to get docs for Julia functions
#
# To get docs for a function you're not familiar with, precede it with a question mark. (This works at the REPL too!)

# %%
?println

# %% [markdown]
# ## How to use shell commands ;
#
# Type `;` and then you can use shell commands. For example,

# %%
;ls

# %%
;pwd

# %% [markdown]
# Shell commands also work at the REPL!

# %%
;mkdir -p testdir2

# %%
;ls

# %% [markdown]
# #Optional to tasks to run later or spare time
#
# ```
# # The cells below will help reproduce plots for Iris data set, but a lot packages are needed, installation takes time so be patient
# ```

# %%
#install packages
using Pkg;
Pkg.add("Gadfly")
Pkg.add("RData")
Pkg.add("RDatasets" )

# %%
#load packages
using Gadfly, RData, RDatasets

# %%
set_default_plot_size(10inch, 9inch/2)

# %%
a=dataset("datasets","iris")
typeof(a)

# %%
a

# %%
plot(a, x ="PetalWidth", y="SepalLength", color="Species")

# %%
using Gadfly
using RData, RDatasets
set_default_plot_size(9inch, 9inch/2)
plot(dataset("datasets","iris"), x ="SepalWidth", y="SepalLength", color="Species")
